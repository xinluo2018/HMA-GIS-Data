# %%
import os
import warnings
warnings.filterwarnings('ignore')
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.io.shapereader import Reader
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
path_basins_vörösmarty2010 = 'data/basins/asia_Vörösmarty2010_6min.gpkg'  
path_basins_lehner2013 = 'data/basins/asia_Lehner2013_levels/hybas_as_lev03_v1c.gpkg'  ### HydroSHEDS dataset
path_hma_gtng = 'data/extents/HMA/gtng_202307_hma_subregions.gpkg'

# %%
hma_gtng = gpd.read_file(path_hma_gtng)
hma_basins_vörösmarty2010 = gpd.read_file(path_basins_vörösmarty2010)
hma_basins_lehner2013 = gpd.read_file(path_basins_lehner2013)
hma_basins_lehner2013.head()
# Out:
#      HYBAS_ID  NEXT_DOWN   NEXT_SINK    MAIN_BAS  DIST_SINK  DIST_MAIN  \
# 0  4030000010          0  4030000010  4030000010        0.0        0.0
# 1  4030000880          0  4030000880  4030000880        0.0        0.0
# 2  4030000890          0  4030000890  4030000890        0.0        0.0
# 3  4030003020          0  4030003020  4030003020        0.0        0.0
# 4  4030006940          0  4030006940  4030006940        0.0        0.0
#
#     SUB_AREA    UP_AREA  PFAF_ID  ENDO  COAST  ORDER  SORT  \
# 0   105274.5   105274.5      421     0      1      0     1
# 1  2238972.5  2238972.5      422     0      0      1     2
# 2   161519.5   161519.5      423     0      1      0     3
# 3   523780.2   523780.2      424     0      1      0     4
# 4   342457.3   342457.3      431     0      1      0     5
#
#                                             geometry
# 0  MULTIPOLYGON (((138.20694 54.69583, 138.20201 ...
# 1  MULTIPOLYGON (((115.33333 43.95000, 115.33333 ...
# 2  MULTIPOLYGON (((140.85694 53.06250, 140.85201 ...
# 3  MULTIPOLYGON (((126.23611 37.75000, 126.22704 ...
# 4  MULTIPOLYGON (((118.51111 38.91667, 118.50499 ...

# %%
# warnings.filterwarnings('ignore')
plt.rcParams.update({'font.size':12})
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1,projection=ccrs.PlateCarree())
# ax.set_extent([50.0, 125.0, 8.0, 47.0])
ax.set_extent([65.0, 107.0, 24.0, 46.0])
ax.gridlines(draw_labels=True, linewidth=0.5, alpha=0.5, zorder=1)
hma_gtng.plot(ax=ax, edgecolor='red', facecolor='none', linestyle='-', linewidth=0.5)
hma_basins_vörösmarty2010.plot(ax=ax, edgecolor='blue', facecolor='none', linestyle='-', linewidth=1)
hma_basins_lehner2013.plot(ax=ax, edgecolor='green', facecolor='none', linestyle='-', linewidth=1)
ax.stock_img(); ax.coastlines()
ax.set_title('hma basins', fontsize=14)
# plt.savefig('figures/hma_hydro_basins.png', bbox_inches='tight', dpi=100)
