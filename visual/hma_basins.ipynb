# %% [markdown]
# ### Check the basins in the HMA region.

# %%
import numpy as np
import geopandas as gpd
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
path_basins_vörösmarty2010 = 'data/basins/asia_Vörösmarty2010_6min.gpkg'  
path_basins_lehner2013 = 'data/basins/asia_Lehner2013_levels/hybas_as_lev03_v1c.gpkg'  ### HydroSHEDS dataset
path_basins_lehner2013_l4 = 'data/basins/asia_Lehner2013_levels/hybas_as_lev04_v1c.gpkg'  ### HydroSHEDS dataset
path_basins_lehner2013_l5 = 'data/basins/asia_Lehner2013_levels/hybas_as_lev05_v1c.gpkg'  ### HydroSHEDS dataset
path_hma_gtng = 'data/extents/HMA/gtng_202307_hma_subregions.gpkg'

# %%
hma_gtng = gpd.read_file(path_hma_gtng)
hma_gtng_merged = hma_gtng.dissolve()
hma_basins_vörösmarty2010 = gpd.read_file(path_basins_vörösmarty2010)
hma_basins_lehner2013 = gpd.read_file(path_basins_lehner2013)
hma_basins_lehner2013_l4 = gpd.read_file(path_basins_lehner2013_l4)
hma_basins_lehner2013_l5 = gpd.read_file(path_basins_lehner2013_l5)
hma_basins_lehner2013.head(2)
# Out:
#      HYBAS_ID  NEXT_DOWN   NEXT_SINK    MAIN_BAS  DIST_SINK  DIST_MAIN  \
# 0  4030000010          0  4030000010  4030000010        0.0        0.0
# 1  4030000880          0  4030000880  4030000880        0.0        0.0
#
#     SUB_AREA    UP_AREA  PFAF_ID  ENDO  COAST  ORDER  SORT  \
# 0   105274.5   105274.5      421     0      1      0     1
# 1  2238972.5  2238972.5      422     0      0      1     2
#
#                                             geometry
# 0  MULTIPOLYGON (((138.20694 54.69583, 138.20201 ...
# 1  MULTIPOLYGON (((115.33333 43.95000, 115.33333 ...

# %%
plt.rcParams.update({'font.size':12})
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1,projection=ccrs.PlateCarree())
ax.set_extent([50.0, 125.0, 8.0, 47.0])
# ax.set_extent([65.0, 107.0, 24.0, 46.0])
ax.gridlines(draw_labels=True, linewidth=0.5, alpha=0.5, zorder=1)
hma_gtng_merged.plot(ax=ax, edgecolor='black', facecolor='none', linestyle='-', legend=True, linewidth=0.6)
hma_basins_vörösmarty2010.plot(ax=ax, edgecolor='brown', facecolor='none', linestyle='-', legend=True, linewidth=0.4)
hma_basins_lehner2013.plot(ax=ax, edgecolor='green', facecolor='none', linestyle='-', linewidth=0.4)
ax.stock_img(); ax.coastlines()
# ax.legend()
ax.set_title('hma basins', fontsize=14)
# plt.savefig('figures/hma_hydro_basins.png', bbox_inches='tight', dpi=100)

# %% [markdown]
# #### hma basins from different data

# %%
plt.rcParams.update({'font.size':12})
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1,projection=ccrs.PlateCarree())
ax.set_extent([50.0, 125.0, 8.0, 47.0])
# ax.set_extent([65.0, 107.0, 24.0, 46.0])
ax.gridlines(draw_labels=True, linewidth=0.5, alpha=0.5, zorder=1)
hma_gtng_merged.plot(ax=ax, edgecolor='black', facecolor='none', linestyle='-', legend=True, linewidth=0.6)
hma_basins_vörösmarty2010.plot(ax=ax, edgecolor='brown', facecolor='none', linestyle='-', legend=True, linewidth=0.4)
hma_basins_lehner2013.plot(ax=ax, edgecolor='green', facecolor='none', linestyle='-', linewidth=0.4)
ax.stock_img(); ax.coastlines()
legend_patches = [
  mpatches.Patch(edgecolor='brown', facecolor='none', label='Vörösmarty 2010'),
  mpatches.Patch(edgecolor='green', facecolor='none', label='Lehner 2013')]
ax.legend(handles=legend_patches, loc='lower left')
ax.set_title('hma basins from different data', fontsize=14)
# plt.savefig('figures/hma_hydro_basins.png', bbox_inches='tight', dpi=100)

# %% [markdown]
# #### hma lehner2013 basins at different level

# %%
plt.rcParams.update({'font.size':12})
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1,projection=ccrs.PlateCarree())
ax.set_extent([65.0, 107.0, 24.0, 46.0])
ax.gridlines(draw_labels=True, linewidth=0.5, alpha=0.5, zorder=1)
hma_gtng_merged.plot(ax=ax, edgecolor='black', facecolor='none',  linestyle='-', linewidth=0.4)
hma_basins_lehner2013_l5.plot(ax=ax, edgecolor='orange', facecolor='none', linestyle='-', linewidth=0.4)
hma_basins_lehner2013_l4.plot(ax=ax, edgecolor='green', facecolor='none', linestyle='-', linewidth=0.4)
ax.stock_img();
legend_patches = [
    mpatches.Patch(edgecolor='orange', facecolor='none', label='level 5'),
    mpatches.Patch(edgecolor='green', facecolor='none', label='level 4')]
ax.legend(handles=legend_patches, loc='lower left')
ax.set_title('hma lehner2013 basins at different level', fontsize=14)
# plt.savefig('figures/hma_hydro_basins.png', bbox_inches='tight', dpi=100)
# Out:
# Text(0.5, 1.0, 'hma lehner2013 basins at different level')
