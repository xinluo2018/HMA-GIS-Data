# %%
import warnings
warnings.filterwarnings('ignore')
import cartopy.crs as ccrs # type: ignore
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
path_hma_gtng = 'data/extents/HMA/gtng_202307_hma_subregions.gpkg'
path_hma_rgi70_reg = 'data/extents/HMA/gtng_202307_hma_subregions.gpkg'
path_hma_rgi70_lager2 = 'data/glaciers/rgi70/rgi70_hma_larger2.gpkg'   ### glacier

# %%
### read in data
hma_gtng = gpd.read_file(path_hma_gtng)
hma_rgi70_reg = gpd.read_file(path_hma_rgi70_reg)
hma_glaciers = gpd.read_file(path_hma_rgi70_lager2)
hma_glaciers.head(2)
# Out:
#                     rgi_id o1region o2region        glims_id  anlys_id  \
# 0  RGI2000-v7.0-G-13-00248       13    13-01  G068125E39075N    804889
# 1  RGI2000-v7.0-G-13-00358       13    13-01  G068341E39155N    805183
# 2  RGI2000-v7.0-G-13-00658       13    13-01  G068548E39007N    805349
# 3  RGI2000-v7.0-G-13-00665       13    13-01  G068515E38986N    805309
# 4  RGI2000-v7.0-G-13-01066       13    13-01  G069044E39009N    805743
#
#    subm_id             src_date     cenlon     cenlat  utm_zone  ...  \
# 0      752  2002-07-10T00:00:00  68.126015  39.073924        42  ...
# 1      752  2002-07-10T00:00:00  68.344637  39.153419        42  ...
# 2      752  2002-07-10T00:00:00  68.544901  39.011764        42  ...
# 3      752  2002-07-10T00:00:00  68.518540  38.992543        42  ...
# 4      752  2002-07-10T00:00:00  69.057885  39.006787        42  ...
#
#       zmin_m     zmax_m     zmed_m    zmean_m  slope_deg  aspect_deg  \
# ...

# %%
## glaciers
plt.rcParams.update({'font.size':14})
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1,1,1,projection=ccrs.PlateCarree())
ax.set_extent([65.0, 107.0, 24.0, 46.0])
ax.gridlines(draw_labels=True, linewidth=0.5, alpha=0.5, zorder=1)
hma_gtng.plot(ax=ax, edgecolor='black', linestyle='-', facecolor='none', linewidth=0.5)
hma_glaciers.plot(ax=ax, edgecolor='yellow', facecolor='yellow', linewidth=1.5)
ax.stock_img()
ax.set_title('Distribution of RGI7.0 glaicers (area > 2km2)', fontsize=14)
# plt.savefig('figures/hma_glaciers.png', bbox_inches='tight', dpi=100)
# Out:
# Text(0.5, 1.0, 'Distribution of RGI7.0 glaicers (area > 2km2)')
